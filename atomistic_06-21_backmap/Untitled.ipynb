# %%
import pdbHtools

# %%
index,atomname,resname,resid,chainid,x,y,z,alpha,beta,segid,element=pdbHtools.pdbread("at_01_ctd.x.0.pdb",2273,0)
# Out:
# here ATOM      0    P   G 0   0      169.51  -25.26   22.36  1.00  0.00
#
# here ATOM      1  OP1   G 0   0      168.24  -24.48   22.34  1.00  0.00
#
# here ATOM      2  OP2   G 0   0      169.46  -26.74   22.32  1.00  0.00
#
# here ATOM      3  O5'   G 0   0      170.46  -24.75   21.18  1.00  0.00
#
# here ATOM      4  C5'   G 0   0      170.81  -23.38   21.07  1.00  0.00
#
# here ATOM      5  C4'   G 0   0      171.91  -23.26   20.04  1.00  0.00
#
# here ATOM      6  O4'   G 0   0      173.08  -23.99   20.51  1.00  0.00
#
# here ATOM      7  C3'   G 0   0      171.63  -23.93   18.70  1.00  0.00
#
# here ATOM      8  O3'   G 0   0      170.78  -23.15   17.88  1.00  0.00
#
# here ATOM      9  C2'   G 0   0      173.03  -24.09   18.14  1.00  0.00
#
# here ATOM     10  O2'   G 0   0      173.57  -22.88   17.63  1.00  0.00
#
# here ATOM     11  C1'   G 0   0      173.78  -24.52   19.40  1.00  0.00
#
# here ATOM     12   N9   G 0   0      173.88  -25.98   19.53  1.00  0.00
#
# ...

# %%
pdbHtools.writepdb('planes'+str(1)+'sys'+str(0)+'_x.pdb',atomname,resname,resid,chainid,x,y,z,alpha,beta)

# %%
'  G'
